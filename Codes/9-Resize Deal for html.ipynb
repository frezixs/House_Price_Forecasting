# %%
# Import
import pandas as pd
import json
import csv

# %%
# Read File
deal = pd.read_csv('../Resources/Final Deal.csv', low_memory=False)
deal = pd.DataFrame(deal)
deal.head()
# Out:
#       City HouseName District  TotalPrice    Price   Floor  Square  \
# 0  Beijing                  7   4150000.0  31680.0    High  131.00
# 1  Beijing                  7   5750000.0  43436.0    High  132.38
# 2  Beijing                  7  10300000.0  52021.0  Middle  198.00
# 3  Beijing                  6   2970000.0  22202.0     Low  134.00
# 4  Beijing                  1   3920000.0  48396.0  Middle   81.00
#
#   ConstructionTime  Bedrooms  LivingRooms  ...   Type       Structure  \
# 0             2005       2.0          2.0  ...  Tower  Steel/Concrete
# 1             2004       2.0          2.0  ...  Tower  Steel/Concrete
# 2             2005       3.0          3.0  ...  Plate  Steel/Concrete
# 3             2008       3.0          3.0  ...  Tower  Steel/Concrete
# 4             1960       2.0          2.0  ...  Plate           Mixed
#
#    Renovation Elevator Subway TradeTime DaysonMarket  Followers         Lng  \
# ...

# %%
# Funtion 
def csv_to_json(csvFilePath, jsonFilePath):
    jsonArray = []
      
    #read csv file
    with open(csvFilePath, encoding='utf-8') as csvf: 
        #load csv file data using csv library's dictionary reader
        csvReader = csv.DictReader(csvf) 

        #convert each csv row into python dict
        for row in csvReader: 
            #add this python dict to json array
            jsonArray.append(row)
  
    #convert python jsonArray to JSON String and write to file
    with open(jsonFilePath, 'w', encoding='utf-8') as jsonf: 
        jsonString = json.dumps(jsonArray,ensure_ascii=False, indent=4)
        jsonf.write(jsonString)

# %%
len(deal)
# Out:
# 162327

# %%
deal = deal.drop(labels=range(5000,159000),axis=0)

# %%
len(deal)
# Out:
# 8327

# %%
deal.head()
# Out:
#       City HouseName District  TotalPrice    Price   Floor  Square  \
# 0  Beijing                  7   4150000.0  31680.0    High  131.00
# 1  Beijing                  7   5750000.0  43436.0    High  132.38
# 2  Beijing                  7  10300000.0  52021.0  Middle  198.00
# 3  Beijing                  6   2970000.0  22202.0     Low  134.00
# 4  Beijing                  1   3920000.0  48396.0  Middle   81.00
#
#   ConstructionTime  Bedrooms  LivingRooms  ...   Type       Structure  \
# 0             2005       2.0          2.0  ...  Tower  Steel/Concrete
# 1             2004       2.0          2.0  ...  Tower  Steel/Concrete
# 2             2005       3.0          3.0  ...  Plate  Steel/Concrete
# 3             2008       3.0          3.0  ...  Tower  Steel/Concrete
# 4             1960       2.0          2.0  ...  Plate           Mixed
#
#    Renovation Elevator Subway TradeTime DaysonMarket  Followers         Lng  \
# ...

# %%
deal.to_csv('../Resources/Deal_html.csv', index=False)

# %%
# Deal.json
csvFilePath = '../Resources/Deal_html.csv'
jsonFilePath = '../Resources/Final Deal_html.json'
csv_to_json(csvFilePath, jsonFilePath)
