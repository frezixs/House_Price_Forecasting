# %%
# Import
import pandas as pd
from sqlalchemy import create_engine
from config import db_password, baidu_api
import requests
import json

# %%
# Read File
beijing = pd.read_csv('../Resources/Beijing Deals Information (not Cleaned).csv', encoding="gb2312", low_memory=False)
shanghai = pd.read_csv('../Resources/Shanghai Deals Information (not Cleaned).csv')
pd.set_option('display.max_columns', None)

# %%
# Time
def tradeTime_Year(x):
    return x[0:4]

# %%
# Beijing Cleaning

# Drop NA value
beijing = beijing.dropna()

# Cleaning 'floor'
beijing['floor'] = beijing.apply(lambda x: x.floor[0] if x.floor != "" else 0, axis=1)

# Covert Chinese Character to numbers
beijing['floor'] = beijing['floor'].str.replace('高', 'High')
beijing['floor'] = beijing['floor'].str.replace('顶', 'High')
beijing['floor'] = beijing['floor'].str.replace('中', 'Middle')
beijing['floor'] = beijing['floor'].str.replace('未', 'Middle')
beijing['floor'] = beijing['floor'].str.replace('底', 'Low')
beijing['floor'] = beijing['floor'].str.replace('低', 'Low')
beijing['floor'] = beijing['floor'].str.replace('低楼层楼层','Low')

# Drop unnecssary columns
beijing = beijing.drop(columns=['url','id','Cid','fiveYearsProperty','communityAverage', 'ladderRatio'])

# Change Time
beijing['tradeTime'] = beijing['tradeTime'].apply(tradeTime_Year)

# Put NaN in to unknown value 
beijing['constructionTime'] = beijing['constructionTime'].str.replace('未知','NaN')

# Change Building Type
beijing['buildingType'] = beijing['buildingType'].map({
    1.0 : 'Tower',
    2.0 : 'Bungalow',
    3.0 : 'Plate & Tower',
    4.0 : 'Plate'})

# Change renovation condition
beijing['renovationCondition'] = beijing['renovationCondition'].map({
    1:'Other',
    2:'Rough',
    3:'Simplicity',
    4:'HardCover'})

# Change building structure
beijing['buildingStructure'] = beijing['buildingStructure'].map({
    1: 'Unknown',
    2: 'Mixed',
    3: 'Brick/Wood',
    4: 'Brick/Concrete',
    5: 'Steel',
    6: 'Steel/Concrete'
})

# Change elevator
beijing['elevator'] = beijing['elevator'].map({
    0:'No',
    1:'Yes'
})

# Change subway
beijing['subway'] = beijing['subway'].map({
    0:'No',
    1:'Yes'
})

# Change Total Price
beijing['totalPrice'] = beijing['totalPrice'].astype(int)
beijing['totalPrice'] = beijing['totalPrice']*10000

# Rename
beijing=pd.DataFrame(beijing)
beijing.rename(columns={'livingRoom': 'bedRoom', 'drawingRoom': 'livingRoom'}, inplace=True)


# Add House Name, Change Columns Order
beijing['HouseName'] = ' '
beijing['City'] = 'Beijing'
Beijing_Order = ['City','HouseName','Lng','Lat','tradeTime','DOM','followers','totalPrice','price','square','bedRoom','livingRoom','kitchen','bathRoom','floor','buildingType','constructionTime','renovationCondition','buildingStructure','elevator','subway','district']
beijing = beijing[Beijing_Order]

# Change Datatype:
beijing['City'] = beijing['City'].astype(str)
beijing['HouseName'] = beijing['HouseName'].astype(str)
beijing['Lng'] = beijing['Lng'].astype(str)
beijing['Lat'] = beijing['Lat'].astype(str)
beijing['tradeTime'] = beijing['tradeTime'].astype(str)
beijing['DOM'] = beijing['DOM'].astype(int)
beijing['followers'] = beijing['followers'].astype(int)
beijing['totalPrice'] = beijing['totalPrice'].astype(float)
beijing['price'] = beijing['price'].astype(float)
beijing['square'] = beijing['square'].astype(float)
beijing['bedRoom'] = beijing['bedRoom'].astype(float)
beijing['livingRoom'] = beijing['livingRoom'].astype(str)
beijing['kitchen'] = beijing['kitchen'].astype(str)
beijing['bathRoom'] = beijing['bathRoom'].astype(str)
beijing['floor'] = beijing['floor'].astype(str)
beijing['buildingType'] = beijing['buildingType'].astype(str)
beijing['constructionTime'] = beijing['constructionTime'].astype(str)
beijing['renovationCondition'] = beijing['renovationCondition'].astype(str)
beijing['buildingStructure'] = beijing['buildingStructure'].astype(str)
beijing['elevator'] = beijing['elevator'].astype(str)
beijing['subway'] = beijing['subway'].astype(str)
beijing['district'] = beijing['district'].astype(str)

# %%
# Shanghai Cleaning

# Drop NA value
shanghai = shanghai.dropna()

# Change columns name and drop columns 
shanghai = shanghai.rename(columns={
        '0': 'houseInfo',
        '1': 'floor',
        '2': 'square',
        '3': 'floorType',
        '4': 'squareInside',
        '5': 'buildingType',
        '6': 'Orientation',
        '7': 'constructionTime',
        '8': 'renovationCondition',
        '9': 'buildingStructure',
        '10': 'heatMethod',
        '11': 'ladderRatio',
        '12': 'elevator',
        '13': 'id',
        '14': 'transactionOwnership',
        '15': 'listDate',
        '16': 'housePurpose',
        '17': 'lifeofHouse',
        '18': 'propertyOwnership',
        '19': 'listPrice',
        '20': 'DOM',
        '21': 'priceChange',
        '22': 'showTimes',
        '23': 'followers',
        '24': 'views',
        '25': 'totalPrice',
        '26': 'price',
        '27': 'tradeTime',
        '28': 'HouseName'})
shanghai = pd.DataFrame(shanghai)
shanghai = shanghai.drop(['squareInside','heatMethod','ladderRatio','Orientation','transactionOwnership','listDate','housePurpose','lifeofHouse','propertyOwnership','listPrice','priceChange','showTimes','views'], axis=1)

# Get House Info
shanghai['bedRoom'] = shanghai.apply(lambda x: x.houseInfo[0] if x.houseInfo != "" else 0, axis=1)
shanghai['livingRoom'] = shanghai.apply(lambda x: x.houseInfo[2] if x.houseInfo != "" else 0, axis=1)
shanghai['kitchen'] = shanghai.apply(lambda x: x.houseInfo[4] if x.houseInfo != "" else 0, axis=1)
shanghai['bathRoom'] = shanghai.apply(lambda x: x.houseInfo[6] if x.houseInfo != "" else 0, axis=1)
shanghai = shanghai.drop(columns='houseInfo')

# Get Floor Info
shanghai['floor'] = shanghai.apply(lambda x: x.floor[0:3] if x.floor != "" else 0, axis=1)
shanghai['floor'] = shanghai['floor'].str.replace('顶层', 'High')
shanghai['floor'] = shanghai['floor'].str.replace('底层', 'Low')
shanghai['floor'] = shanghai['floor'].str.replace('高楼层', 'High')
shanghai['floor'] = shanghai['floor'].str.replace('低楼层', 'Low')
shanghai['floor'] = shanghai['floor'].str.replace('中楼层', 'Middle')

# Clean Square
shanghai['square'] = shanghai['square'].str.extract(r'(\d+\.?\d*)')

# Clean ConstructionTime
shanghai['constructionTime'] = shanghai['constructionTime'].str.replace('未知','NaN')

# Clean DOM
shanghai['DOM']  = shanghai['DOM'].str.extract(r'(\d+)')

# Clean bedRoom
shanghai['bedRoom'] = shanghai['bedRoom'].str.replace('车', 'NaN')

#Clean followers
shanghai['followers'] = shanghai['followers'].str.extract(r'(\d+)')

# Get Total Price
shanghai['totalPrice'] = shanghai['totalPrice'].str.extract(r'(\d+)')
#Total Price
shanghai['totalPrice'] = shanghai['totalPrice'].astype(int)
shanghai['totalPrice'] = shanghai['totalPrice']*10000

# Change Time
shanghai['tradeTime'] = shanghai['tradeTime'].apply(tradeTime_Year)

# Clean Building Type
shanghai['buildingType'] = shanghai['buildingType'].str.replace('板楼', 'Plate')
shanghai['buildingType'] = shanghai['buildingType'].str.replace('塔楼', 'Tower')
shanghai['buildingType'] = shanghai['buildingType'].str.replace('板塔结合','Plate & Tower')
shanghai['buildingType'] = shanghai['buildingType'].str.replace('暂无数据', 'Other')
shanghai['buildingType'] = shanghai['buildingType'].str.replace('平房', 'Bungalow')

# Clean Building Structure
shanghai['buildingStructure'] = shanghai['buildingStructure'].str.replace('钢混结构','Steel/Concrete')
shanghai['buildingStructure'] = shanghai['buildingStructure'].str.replace('砖混结构','Brick/Concrete')
shanghai['buildingStructure'] = shanghai['buildingStructure'].str.replace('混合结构','Mixed')
shanghai['buildingStructure'] = shanghai['buildingStructure'].str.replace('未知结构','Unknown')
shanghai['buildingStructure'] = shanghai['buildingStructure'].str.replace('砖木结构','Brick/Wood')
shanghai['buildingStructure'] = shanghai['buildingStructure'].str.replace('框架结构','Steel') 

# Clean Floor Type
shanghai['floorType'] = shanghai['floorType'].str.replace('平层','Flat')
shanghai['floorType'] = shanghai['floorType'].str.replace('复式','Duplex')
shanghai['floorType'] = shanghai['floorType'].str.replace('错层','Split-Level')
shanghai['floorType'] = shanghai['floorType'].str.replace('暂无数据','Other')

# Clean Renovation Condition
shanghai['renovationCondition'] = shanghai['renovationCondition'].str.replace('毛坯','Rough')
shanghai['renovationCondition'] = shanghai['renovationCondition'].str.replace('简装','Simplicity')
shanghai['renovationCondition'] = shanghai['renovationCondition'].str.replace('精装','Hardcover')
shanghai['renovationCondition'] = shanghai['renovationCondition'].str.replace('其他','Other')

# Clean Elevator
shanghai['elevator'] = shanghai['elevator'].str.replace('暂无数据','Unknown')
shanghai['elevator'] = shanghai['elevator'].str.replace('有','Yes')
shanghai['elevator'] = shanghai['elevator'].str.replace('无','No')

# Lat & Lng
shanghai['Lng'] = ' '
shanghai['Lat'] = ' '

# HouseName
shanghai[['HouseName', 'HouseName1']] = shanghai['HouseName'].str.split(' ', 1, expand=True)

# Add district & subway Columns, Change Columns Order
shanghai['district'] = 'Unknown'
shanghai['subway'] = 'Unknown'
shanghai['City'] = 'Shanghai'
shanghai_Order = ['City','HouseName','Lng','Lat','tradeTime','DOM','followers','totalPrice','price','square','bedRoom','livingRoom','kitchen','bathRoom','floor','buildingType','constructionTime','renovationCondition','buildingStructure','elevator','subway','district']
shanghai = shanghai[shanghai_Order]

#Get Lat & Lng
Lng = []
Lat = []
for i in shanghai.values:
    address = f'上海市'+i[1]
    url = 'http://api.map.baidu.com/geocoding/v3/?address={}&output=json&ak={}'.format(address,baidu_api)
    data = requests.get(url)
    json_data = json.loads(data.text)
    i[2] = json_data['result']['location']['lng']
    Lng.append(i[2])
    i[3] = json_data['result']['location']['lat']
    Lat.append(i[3])
    print(i)
    
shanghai['Lng'] = Lng
shanghai['Lat'] = Lat

# Change Datatype:
shanghai['City'] = shanghai['City'].astype(str)
shanghai['HouseName'] = shanghai['HouseName'].astype(str)
shanghai['Lng'] = shanghai['Lng'].astype(str)
shanghai['Lat'] = shanghai['Lat'].astype(str)
shanghai['tradeTime'] = shanghai['tradeTime'].astype(str)
shanghai['DOM'] = shanghai['DOM'].astype(int)
shanghai['followers'] = shanghai['followers'].astype(int)
shanghai['totalPrice'] = shanghai['totalPrice'].astype(float)
shanghai['price'] = shanghai['price'].astype(float)
shanghai['square'] = shanghai['square'].astype(float)
shanghai['bedRoom'] = shanghai['bedRoom'].astype(float)
shanghai['livingRoom'] = shanghai['livingRoom'].astype(str)
shanghai['kitchen'] = shanghai['kitchen'].astype(str)
shanghai['bathRoom'] = shanghai['bathRoom'].astype(str)
shanghai['floor'] = shanghai['floor'].astype(str)
shanghai['buildingType'] = shanghai['buildingType'].astype(str)
shanghai['constructionTime'] = shanghai['constructionTime'].astype(str)
shanghai['renovationCondition'] = shanghai['renovationCondition'].astype(str)
shanghai['buildingStructure'] = shanghai['buildingStructure'].astype(str)
shanghai['elevator'] = shanghai['elevator'].astype(str)
shanghai['subway'] = shanghai['subway'].astype(str)
shanghai['district'] = shanghai['district'].astype(str)
# Out:
# ['Shanghai' '海棠馨苑南区' 121.24979633400042 31.185656967038447 '2021' '7' '3'
#  2480000 50335 '49.27' '1' '1' '1' '1' 'Middle' 'Plate       ' 'NaN '
#  'Simplicity     ' 'Steel/Concrete  ' 'Yes           ' 'Unknown' 'Unknown']
# ['Shanghai' '建业新村' 121.52940623076657 31.19570155584116 '2021' '13' '2'
#  3260000 69362 '47' '1' '1' '1' '1' 'Low' 'Plate       ' '1998 '
#  'Simplicity     ' 'Brick/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '金地自在城(二期)' 121.2576206648229 31.131183623683715 '2021' '30'
#  '10' 4340000 48449 '89.58' '2' '2' '1' '1' 'Middle' 'Plate       '
#  '2014 ' 'Hardcover     ' 'Steel/Concrete  ' 'Yes           ' 'Unknown'
#  'Unknown']
# ['Shanghai' '上海捷克住宅小区(公寓)' 121.28396221627528 31.16655180125927 '2021' '9'
#  '0' 4450000 49916 '89.15' '2' '1' '1' '1' 'High' 'Plate       ' '2008 '
#  'Simplicity     ' 'Steel/Concrete  ' 'Yes           ' 'Unknown' 'Unknown']
# ['Shanghai' '和源名城' 121.47306271256971 31.32376435878371 '2021' '9' '11'
#  5570000 69073 '80.64' '2' '1' '1' '1' 'High' 'Plate       ' '2014 '
#  'Hardcover     ' 'Steel/Concrete  ' 'Yes           ' 'Unknown' 'Unknown']
# ['Shanghai' '新中新村' 121.48301521897586 31.286662472632987 '2021' '24' '13'
#  2230000 63842 '34.93' '1' '1' '1' '1' 'Middle' 'Plate       ' '1998 '
#  'Simplicity     ' 'Steel/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '欣乐苑（东苑）' 121.24390946850188 31.190426047118553 '2021' '3' '4'
#  2480000 44709 '55.47' '1' '1' '0' '1' 'High' 'Plate       ' '2013 '
#  'Hardcover     ' 'Steel/Concrete  ' 'Unknown           ' 'Unknown'
#  'Unknown']
# ['Shanghai' '西湖苑' 121.3687300072494 31.119136891501313 '2021' '41' '16'
#  1720000 52697 '32.64' '1' '0' '1' '1' 'High' 'Plate       ' '1994 '
#  'Simplicity     ' 'Brick/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '长春新苑' 121.42346600773612 31.184641891110314 '2021' '18' '22'
#  6350000 92945 '68.32' '2' '1' '1' '1' 'Low' 'Plate       ' '1996 '
#  'Hardcover     ' 'Steel/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '维罗纳贵都' 121.21118258182348 31.024229484553324 '2021' '1' '0'
#  4520000 43073 '104.94' '4' '2' '1' '1' 'High' 'Plate       ' '2006 '
#  'Hardcover     ' 'Steel/Concrete  ' 'Yes           ' 'Unknown' 'Unknown']
# ['Shanghai' '中浩云花园' 121.42282713285742 31.26834138837375 '2021' '11' '0'
#  9390000 88585 '106' '2' '2' '1' '1' 'High' 'Plate       ' '2008 '
#  'Hardcover     ' 'Steel/Concrete  ' 'Yes           ' 'Unknown' 'Unknown']
# ['Shanghai' '德盈佳园' 121.80528052406945 31.063667808141023 '2021' '21' '7'
#  2310000 25117 '91.97' '2' '2' '1' '1' 'Low' 'Plate       ' '2008 '
#  'Hardcover     ' 'Steel/Concrete  ' 'Yes           ' 'Unknown' 'Unknown']
# ['Shanghai' '丹桂佳苑' 121.76749689601426 31.031040109428755 '2021' '82' '41'
#  1520000 25174 '60.38' '1' '1' '1' '1' 'Middle' 'Plate       ' '2008 '
#  'Rough     ' 'Steel/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '星云苑' 121.54886245014606 31.316292331481492 '2021' '38' '92'
#  8200000 76351 '107.4' '2' '2' '1' '1' 'Middle' 'Plate       ' '2007 '
#  'Hardcover     ' 'Steel/Concrete  ' 'Yes           ' 'Unknown' 'Unknown']
# ['Shanghai' '洛川中路1100弄' 121.4560534773994 31.27070760991036 '2021' '132'
#  '69' 3650000 89991 '40.56' '1' '1' '1' '1' 'Middle' 'Plate       '
#  '1985 ' 'Hardcover     ' 'Brick/Concrete  ' 'No           ' 'Unknown'
#  'Unknown']
# ['Shanghai' '瑞丰园' 121.38390660934881 31.32289252715869 '2021' '56' '15'
#  4950000 53307 '92.86' '3' '1' '1' '1' 'High' 'Plate       ' '2005 '
#  'Hardcover     ' 'Steel/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '盛大花园' 121.46088097121 31.18401189438163 '2021' '22' '76'
#  12450000 112203 '110.96' '2' '2' '1' '2' 'Low' 'Plate       ' '2003 '
#  'Hardcover     ' 'Steel/Concrete  ' 'Yes           ' 'Unknown' 'Unknown']
# ['Shanghai' '景峰苑' 121.43559915076774 31.284353978763125 '2021' '26' '41'
#  2050000 60795 '33.72' '1' '1' '1' '1' 'High' 'Plate       ' '1995 '
#  'Hardcover     ' 'Brick/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '金桂苑(徐汇)' 121.42011029767305 31.16867240361738 '2021' '47'
#  '23' 9950000 71465 '139.23' '3' '1' '1' '2' 'Low' 'Tower       ' '1996 '
#  'Hardcover     ' 'Steel/Concrete  ' 'Yes           ' 'Unknown' 'Unknown']
# ['Shanghai' '瞿四小区' 121.49284187278006 31.206768486138067 '2021' '7' '7'
#  3700000 107653 '34.37' '1' '0' '1' '1' 'Middle' 'Plate       ' '1988 '
#  'Hardcover     ' 'Steel/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '闵浦新苑六村' 121.54246175389582 31.0652333268748 '2021' '27' '57'
#  2580000 42498 '60.71' '2' '1' '0' '1' 'High' 'Plate       ' '2007 '
#  'Hardcover     ' 'Steel/Concrete  ' 'Yes           ' 'Unknown' 'Unknown']
# ['Shanghai' '华松西区（仙霞西路700弄）' 121.3635668166697 31.21531336787089 '2021'
#  '5' '5' 3970000 61030 '65.05' '2' '1' '1' '1' 'Middle' 'Plate       '
#  '1995 ' 'Simplicity     ' 'Steel/Concrete  ' 'No           ' 'Unknown'
#  'Unknown']
# ['Shanghai' '名都城(公寓)' 121.54061295132573 31.035734423504866 '2021' '20'
#  '22' 11800000 85508 '138' '3' '2' '1' '2' 'Middle' 'Plate & Tower       '
#  '1999 ' 'Simplicity     ' 'Steel/Concrete  ' 'Yes           ' 'Unknown'
#  'Unknown']
# ['Shanghai' '青水湾公寓' 121.14339896329598 31.16460125588742 '2021' '24' '22'
#  4700000 37640 '124.87' '3' '2' '0' '2' 'Middle' 'Plate       ' '2005 '
#  'Hardcover     ' 'Steel/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '新南家园' 121.45204766363875 30.998924869263565 '2021' '140' '63'
#  3350000 25075 '133.6' '3' '1' '1' '2' 'Middle' 'Plate       ' '2005 '
#  'Simplicity     ' 'Steel/Concrete  ' 'Yes           ' 'Unknown' 'Unknown']
# ['Shanghai' '临波大楼' 121.35946659099994 30.722049557148154 '2021' '165' '3'
#  1030000 13919 '74' '2' '1' '1' '1' 'Low' 'Tower       ' '1992 '
#  'Simplicity     ' 'Mixed  ' 'Unknown           ' 'Unknown' 'Unknown']
# ['Shanghai' '茉莉雅苑' 121.252152409692 31.109561868731348 '2021' '88' '132'
#  2460000 36044 '68.25' '2' '1' '1' '1' 'Middle' 'Plate       ' '2012 '
#  'Hardcover     ' 'Steel/Concrete  ' 'Yes           ' 'Unknown' 'Unknown']
# ['Shanghai' '城东新村（二区）' 121.13059846910099 31.150502203332227 '2021' '4'
#  '4' 1500000 40150 '37.36' '1' '1' '1' '1' 'High' 'Plate       ' '1992 '
#  'Hardcover     ' 'Brick/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '新凯城尚樱苑' 121.2490423861859 31.12087754536027 '2021' '254' '51'
#  2740000 37300 '73.46' '2' '2' '1' '1' 'Middle' 'Plate       ' '2014 '
#  'Rough     ' 'Steel/Concrete  ' 'Yes           ' 'Unknown' 'Unknown']
# ['Shanghai' '龙柏五村' 121.37541483753245 31.18177230939203 '2021' '9' '7'
#  4680000 70208 '66.66' '2' '1' '1' '1' 'Middle' 'Plate       ' '1995 '
#  'Simplicity     ' 'Brick/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '古华新村' 121.47338331780624 30.921941969406564 '2021' '2' '0'
#  1250000 23961 '52.17' '2' '1' '1' '1' 'High' 'Plate       ' 'NaN '
#  'Other     ' 'Brick/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '翔殷路491弄' 121.54318372203419 31.312227373057752 '2021' '272'
#  '82' 4060000 79421 '51.12' '2' '1' '1' '1' 'Low' 'Plate       ' '1993 '
#  'Simplicity     ' 'Brick/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '一品漫城(五期)' 121.49752824279508 31.121817107885146 '2021' '19'
#  '0' 9000000 94737 '95' '2' '2' '1' '1' 'High' 'Plate       ' '2014 '
#  'Hardcover     ' 'Steel/Concrete  ' 'Yes           ' 'Unknown' 'Unknown']
# ['Shanghai' '万科早城(一期)' 121.49255396586412 31.110065833478828 '2021' '126'
#  '0' 1130000 18226 '62' '1' '1' '1' '1' 'Middle' 'Plate       ' '2013 '
#  'Other     ' 'Steel/Concrete  ' 'Yes           ' 'Unknown' 'Unknown']
# ['Shanghai' '正力公寓' 121.43887077943508 31.210203889784854 '2021' '412' '26'
#  5800000 86879 '66.76' '1' '1' '1' '1' 'Middle' 'Plate & Tower       '
#  'NaN ' 'Simplicity     ' 'Steel/Concrete  ' 'Yes           ' 'Unknown'
#  'Unknown']
# ['Shanghai' '恒盛鼎城圣都汇' 121.39407785314665 31.283983420139585 '2021' '63'
#  '46' 8660000 93049 '93.07' '3' '2' '1' '1' 'Middle' 'Plate       '
#  '2012 ' 'Hardcover     ' 'Steel/Concrete  ' 'Yes           ' 'Unknown'
#  'Unknown']
# ['Shanghai' '凌兆新村(凌兆路256弄)' 121.50353215750157 31.1456496547643 '2021'
#  '31' '23' 4320000 59826 '72.21' '3' '1' '1' '1' 'High' 'Plate       '
#  '1996 ' 'Simplicity     ' 'Brick/Concrete  ' 'No           ' 'Unknown'
#  'Unknown']
# ['Shanghai' '古北新城' 121.40933988410006 31.188370038110765 '2021' '12' '14'
#  5570000 80678 '69.04' '2' '2' '1' '1' 'High' 'Plate       ' '1996 '
#  'Hardcover     ' 'Brick/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '御景龙庭' 121.33068101974656 30.738287841880826 '2021' '323' '8'
#  1720000 18776 '91.5' '2' '2' '1' '1' 'High' 'Plate       ' '2011 '
#  'Rough     ' 'Steel/Concrete  ' 'Yes           ' 'Unknown' 'Unknown']
# ['Shanghai' '海棠新村' 121.35459103784454 30.725997145356192 '2021' '41' '0'
#  840000 13613 '61.71' '2' '1' '1' '1' 'Middle' 'Plate       ' '1988 '
#  'Rough     ' 'Brick/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '红旗五村' 121.40886611777411 31.01773086914705 '2021' '26' '24'
#  1440000 33622 '42.83' '1' '1' '1' '1' 'High' 'Plate       ' '1987 '
#  'Simplicity     ' 'Brick/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '愚园路488弄' 121.44593927600145 31.228570798418172 '2021' '133'
#  '366' 6200000 114118 '54.33' '2' '1' '1' '1' 'Middle' 'Plate       '
#  '1983 ' 'Hardcover     ' 'Brick/Concrete  ' 'No           ' 'Unknown'
#  'Unknown']
# ['Shanghai' '贝港北区（二区）' 121.45281903858016 30.922166881791988 '2021' '88'
#  '11' 1800000 20259 '88.85' '3' '2' '1' '1' 'High' 'Plate       ' '1994 '
#  'Simplicity     ' 'Brick/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '绿地世纪城(二期)' 121.4266513990745 31.240169528868208 '2021' '54'
#  '118' 12300000 109130 '112.71' '3' '2' '1' '1' 'High' 'Plate       '
#  '2003 ' 'Hardcover     ' 'Steel/Concrete  ' 'Yes           ' 'Unknown'
#  'Unknown']
# ['Shanghai' '城南居委小区' 121.71285782269204 31.198189387382293 '2021' '6' '0'
#  2470000 44018 '56' '2' '1' '1' '1' 'Middle' 'Plate       ' '1989 '
#  'Simplicity     ' 'Brick/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '江桥万达广场(嘉定)' 121.35217477568379 31.26535854435243 '2021'
#  '1768' '0' 1190000 21609 '55.07' '1' '1' '1' '1' 'High' 'Tower       '
#  '2011 ' 'Other     ' 'Steel/Concrete  ' 'Yes           ' 'Unknown'
#  'Unknown']
# ['Shanghai' '蓝色城邦(公寓)' 121.81755191631905 30.907849105607053 '2021' '19'
#  '10' 1390000 26055 '53.35' '1' '1' '1' '1' 'Middle' 'Plate       '
#  '2010 ' 'Rough     ' 'Steel/Concrete  ' 'Yes           ' 'Unknown'
#  'Unknown']
# ['Shanghai' '绿地香颂(奉贤)(公寓)' 121.54010028837119 31.13698861720319 '2021'
#  '46' '11' 930000 19375 '48' '1' '1' '1' '1' 'Low' 'Plate       ' '2011 '
#  'Rough     ' 'Steel/Concrete  ' 'Yes           ' 'Unknown' 'Unknown']
# ['Shanghai' '万兆家园(一期)' 121.35769899524797 31.154623871758893 '2021' '6'
#  '6' 5180000 75291 '68.8' '2' '1' '1' '1' 'Middle' 'Plate       ' '2000 '
#  'Hardcover     ' 'Brick/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '金阳小区' 121.43009343629708 31.2288326516261 '2021' '78' '86'
#  3440000 76932 '44.65' '1' '1' '1' '1' 'High' 'Plate       ' '1987 '
#  'Hardcover     ' 'Steel/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '德州五村' 121.50200952966215 31.172721823727052 '2021' '40' '15'
#  5190000 72285 '71.8' '2' '2' '1' '1' 'Middle' 'Plate       ' '1996 '
#  'Hardcover     ' 'Brick/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '新城尚上城' 121.18544127811286 31.290933367540276 '2021' '2' '0'
#  3660000 39783 '92' '2' '2' '1' '1' 'Middle' 'Plate       ' '2013 '
#  'Other     ' 'Steel/Concrete  ' 'Yes           ' 'Unknown' 'Unknown']
# ['Shanghai' '宝华城市之星' 121.43626308837017 31.26044935747112 '2021' '78' '45'
#  19900000 136686 '145.59' '3' '2' '1' '2' 'Low' 'Plate       ' '2018 '
#  'Hardcover     ' 'Steel/Concrete  ' 'Yes           ' 'Unknown' 'Unknown']
# ['Shanghai' '曲阳名邸' 121.48812289427507 31.293069898881157 '2021' '15' '40'
#  8080000 92640 '87.22' '2' '2' '1' '1' 'Low' 'Plate       ' '2005 '
#  'Hardcover     ' 'Steel/Concrete  ' 'Yes           ' 'Unknown' 'Unknown']
# ['Shanghai' '华一新城' 121.40524612623 31.16427379203681 '2021' '39' '14'
#  5820000 107958 '53.91' '1' '1' '1' '1' 'Low' 'Plate       ' '2012 '
#  'Hardcover     ' 'Steel/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '番禺路385弄' 121.43679111234893 31.210389894625358 '2021' '9' '1'
#  3510000 92006 '38.15' '1' '0' '1' '1' 'High' 'Plate       ' '1991 '
#  'Hardcover     ' 'Brick/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '阳明国际花苑五期' 121.39087997536168 31.126574827271213 '2021' '72'
#  '35' 7150000 75407 '94.82' '2' '2' '1' '1' 'High' 'Plate       ' '2004 '
#  'Simplicity     ' 'Steel/Concrete  ' 'Yes           ' 'Unknown' 'Unknown']
# ['Shanghai' '绿地蔷薇九里(公寓)' 121.23648353617313 31.0672587805851 '2021' '262'
#  '84' 7070000 54410 '129.94' '3' '2' '1' '2' 'Low' 'Plate       ' '2013 '
#  'Hardcover     ' 'Steel/Concrete  ' 'Yes           ' 'Unknown' 'Unknown']
# ['Shanghai' '双山小区' 121.43063619248622 31.266822854483696 '2021' '59' '27'
#  4110000 63781 '64.44' '2' '1' '1' '1' 'High' 'Plate       ' '1993 '
#  'Simplicity     ' 'Brick/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '万荣小区' 121.4434830392455 31.291387910096027 '2021' '78' '66'
#  4630000 60505 '76.44' '2' '1' '1' '1' 'High' 'Plate       ' '1994 '
#  'Simplicity     ' 'Brick/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '万顺水原墅(公寓)' 121.42263597344491 31.048741874239887 '2021' '69'
#  '86' 3660000 38125 '96' '2' '2' '1' '1' 'Middle' 'Tower       ' '2012 '
#  'Hardcover     ' 'Steel/Concrete  ' 'Yes           ' 'Unknown' 'Unknown']
# ['Shanghai' '通阁小区' 121.47737197393164 31.26726084666834 '2021' '5' '0'
#  3280000 85306 '38.45' '1' '1' '1' '1' 'Low' 'Plate       ' '1994 '
#  'Hardcover     ' 'Steel/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '菊泉新城(陆翔路358弄)' 121.37587000893436 31.356828865853245 '2021'
#  '46' '53' 3210000 45059 '71.24' '2' '1' '1' '1' 'High' 'Plate       '
#  '2005 ' 'Hardcover     ' 'Steel/Concrete  ' 'No           ' 'Unknown'
#  'Unknown']
# ['Shanghai' '铁路新村(杨浦)' 121.53251993732523 31.265524144657057 '2021' '49'
#  '47' 3580000 67433 '53.09' '2' '1' '1' '1' 'High' 'Plate       ' '1986 '
#  'Hardcover     ' 'Brick/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '中华新路893弄' 121.46198462935958 31.261228396340947 '2021' '69'
#  '55' 3280000 73068 '44.89' '2' '0' '1' '1' 'High' 'Plate       ' '1980 '
#  'Simplicity     ' 'Brick/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '海棠新村' 121.35459103784454 30.725997145356192 '2021' '13' '38'
#  660000 15000 '44' '2' '1' '1' '1' 'High' 'Plate       ' '1988 '
#  'Hardcover     ' 'Brick/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '齐二小区' 121.51987601778065 31.18923686973554 '2021' '3' '0'
#  2350000 57472 '40.89' '1' '1' '1' '1' 'High' 'Plate       ' '1994 '
#  'Simplicity     ' 'Brick/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '恒盛湖畔豪庭' 121.4971610155026 30.933671862755862 '2021' '38' '14'
#  3470000 49424 '70.21' '2' '1' '1' '1' 'Low' 'Plate       ' '2011 '
#  'Hardcover     ' 'Steel/Concrete  ' 'Unknown           ' 'Unknown'
#  'Unknown']
# ['Shanghai' '新城昱翠湾' 121.41883542249329 31.435399825937438 '2021' '1' '0'
#  2750000 36019 '76.35' '2' '1' '1' '1' 'Middle' 'Plate       ' '2014 '
#  'Hardcover     ' 'Steel/Concrete  ' 'Unknown           ' 'Unknown'
#  'Unknown']
# ['Shanghai' '好家园' 121.45348432364086 31.332085641068385 '2021' '134' '199'
#  6580000 72958 '90.19' '2' '2' '1' '1' 'High' 'Plate       ' '2009 '
#  'Hardcover     ' 'Steel/Concrete  ' 'Yes           ' 'Unknown' 'Unknown']
# ['Shanghai' '昆山小区' 121.49525678748253 31.255069065984276 '2021' '67' '97'
#  5800000 93173 '62.25' '2' '2' '1' '1' 'High' 'Plate       ' '1983 '
#  'Simplicity     ' 'Brick/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '华润外滩九里' 121.50992557747718 31.224944303175814 '2021' '319'
#  '163' 32300000 132242 '244.25' '3' '2' '1' '4' 'Low' 'Plate       '
#  '2011 ' 'Hardcover     ' 'Steel/Concrete  ' 'Yes           ' 'Unknown'
#  'Unknown']
# ['Shanghai' '彭新小区' 121.4534120100473 31.315767880431654 '2021' '12' '5'
#  3190000 64602 '49.38' '2' '0' '1' '1' 'Middle' 'Plate       ' '1984 '
#  'Simplicity     ' 'Brick/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '毕加索小镇(二期)(公寓)' 121.65384454051957 31.217518720730133 '2021'
#  '94' '41' 7100000 79295 '89.54' '2' '2' '1' '1' 'Low' 'Plate       '
#  '2011 ' 'Hardcover     ' 'Steel/Concrete  ' 'Yes           ' 'Unknown'
#  'Unknown']
# ['Shanghai' '隽苑' 121.04666978530375 31.118841961785165 '2021' '150' '99'
#  2860000 32500 '88' '3' '2' '1' '1' 'Middle' 'Plate       ' '2017 '
#  'Simplicity     ' 'Steel/Concrete  ' 'Yes           ' 'Unknown' 'Unknown']
# ['Shanghai' '民乐小区' 121.22919136153476 31.024333850539527 '2021' '3' '5'
#  3300000 38920 '84.79' '2' '1' '1' '1' 'Low' 'Plate       ' '1997 '
#  'Hardcover     ' 'Brick/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '南泉小区' 121.52868453211984 31.218927497401634 '2021' '94' '131'
#  3850000 70760 '54.41' '2' '1' '1' '1' 'High' 'Plate       ' '1989 '
#  'Hardcover     ' 'Brick/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '文宝苑' 121.37462235241154 31.353091245963633 '2021' '8' '7'
#  3250000 57350 '56.67' '1' '1' '1' '1' 'Middle' 'Plate       ' '2008 '
#  'Simplicity     ' 'Steel/Concrete  ' 'Yes           ' 'Unknown' 'Unknown']
# ['Shanghai' '万科城花新园' 121.34155698421698 31.159538223336856 '2021' '62'
#  '50' 9180000 81427 '112.74' '3' '2' '1' '1' 'Low' 'Plate       ' '2011 '
#  'Hardcover     ' 'Steel/Concrete  ' 'Yes           ' 'Unknown' 'Unknown']
# ['Shanghai' '广虹公寓' 121.27418038791603 31.177646890404084 '2021' '14' '11'
#  1940000 44422 '43.65' '1' '1' '1' '1' 'Low' 'Plate       ' '1995 '
#  'Rough     ' 'Brick/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '雍华府(公寓)' 121.41343516908951 31.080118992873583 '2021' '2' '0'
#  160000 4185 '37.04' 'NaN' ' ' ' ' ' ' '地下室' 'Other       ' 'NaN '
#  'Other     ' 'Steel/Concrete  ' 'Unknown           ' 'Unknown' 'Unknown']
# ['Shanghai' '绿地领海(商业类)' 121.35648888789547 31.321527116797682 '2021' '40'
#  '1' 1280000 21270 '60.18' '2' '1' '0' '1' 'Middle' 'Tower       ' 'NaN '
#  'Hardcover     ' 'Steel/Concrete  ' 'Yes           ' 'Unknown' 'Unknown']
# ['Shanghai' '水语人家南苑' 121.53868878092337 31.05111580597933 '2021' '11' '2'
#  3230000 43857 '73.65' '2' '1' '1' '1' 'Middle' 'Plate       ' '2010 '
#  'Hardcover     ' 'Steel/Concrete  ' 'Yes           ' 'Unknown' 'Unknown']
# ['Shanghai' '凯德新视界(一期)' 121.81619403771016 30.967591867678497 '2021' '12'
#  '3' 2060000 25890 '79.57' '2' '1' '1' '1' 'High' 'Plate       ' '2015 '
#  'Hardcover     ' 'Steel/Concrete  ' 'Unknown           ' 'Unknown'
#  'Unknown']
# ['Shanghai' '黑山小区' 121.52990425134129 31.313274538098412 '2021' '82' '22'
#  2320000 57087 '40.64' '1' '1' '1' '1' 'High' 'Plate       ' '1986 '
#  'Simplicity     ' 'Brick/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '华强公寓' 121.45215357385837 31.209339645760267 '2021' '47' '36'
#  7500000 136315 '55.02' '2' '1' '1' '1' 'Low' 'Tower       ' '1992 '
#  'Simplicity     ' 'Steel/Concrete  ' 'Yes           ' 'Unknown' 'Unknown']
# ['Shanghai' '紫阳花苑' 121.46058147615298 31.120005367577285 '2021' '36' '210'
#  3990000 70483 '56.61' '2' '1' '1' '1' 'Low' 'Plate       ' '1996 '
#  'Hardcover     ' 'Steel/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '银都新村(1至7区)' 121.40086338347736 31.10000442342667 '2021' '72'
#  '21' 4120000 65335 '63.06' '2' '1' '1' '1' 'Low' 'Plate       ' '1995 '
#  'Simplicity     ' 'Brick/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '保利金爵公寓' 121.65962298054305 31.209474846079928 '2021' '4' '11'
#  6510000 73229 '88.9' '2' '2' '1' '1' 'Middle' 'Plate       ' '2009 '
#  'Hardcover     ' 'Steel/Concrete  ' 'Yes           ' 'Unknown' 'Unknown']
# ['Shanghai' '丝庐雅苑二期' 121.66335885349794 31.040513204485716 '2021' '18'
#  '16' 3490000 38938 '89.63' '2' '2' '1' '1' 'High' 'Plate       ' '2015 '
#  'Rough     ' 'Steel/Concrete  ' 'Yes           ' 'Unknown' 'Unknown']
# ['Shanghai' '嘉实上城名都(公寓)' 121.22697012150024 31.29329863096863 '2021' '15'
#  '10' 2990000 31481 '94.98' '3' '2' '1' '1' 'High' 'Plate       ' '2010 '
#  'Hardcover     ' 'Steel/Concrete  ' 'Yes           ' 'Unknown' 'Unknown']
# ['Shanghai' '三杨新村二街坊' 121.49484464491456 31.162314083560926 '2021' '10'
#  '19' 7000000 92082 '76.02' '2' '1' '1' '1' 'Low' 'Plate       ' '2012 '
#  'Simplicity     ' 'Steel/Concrete  ' 'Yes           ' 'Unknown' 'Unknown']
# ['Shanghai' '红梅小区(嘉定)' 121.37046203010317 31.221199854965864 '2021' '8'
#  '29' 1720000 26204 '65.64' '2' '2' '1' '1' 'Middle' 'Plate       '
#  '1978 ' 'Simplicity     ' 'Brick/Concrete  ' 'No           ' 'Unknown'
#  'Unknown']
# ['Shanghai' '浦江智汇园' 121.52775604354473 31.082101833425632 '2021' '47' '38'
#  6370000 45018 '141.5' '4' '2' '1' '2' 'Low' 'Plate       ' '2010 '
#  'Simplicity     ' 'Steel/Concrete  ' 'Yes           ' 'Unknown' 'Unknown']
# ['Shanghai' '共和新路4699弄' 121.45764231035488 31.324820725532593 '2021' '18'
#  '32' 3560000 61188 '58.1' '2' '1' '1' '1' 'Low' 'Plate       ' '1996 '
#  'Hardcover     ' 'Brick/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '鸿发家园' 121.39180415207034 31.135813830644896 '2021' '113' '80'
#  6970000 80887 '86.17' '2' '2' '1' '1' 'High' 'Plate       ' '2002 '
#  'Hardcover     ' 'Steel/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '七韵美地苑' 121.35908157725838 31.1726367786646 '2021' '29' '22'
#  6620000 83819 '78.98' '2' '2' '1' '1' 'Low' 'Plate       ' '2010 '
#  'Hardcover     ' 'Steel/Concrete  ' 'Yes           ' 'Unknown' 'Unknown']
# ['Shanghai' '阳光城MODO自由区' 121.59465599894207 31.30637631388828 '2021' '556'
#  '1' 1600000 32561 '49.14' '1' '1' '1' '1' 'High' 'Tower       ' '2014 '
#  'Hardcover     ' 'Steel/Concrete  ' 'Yes           ' 'Unknown' 'Unknown']
# ['Shanghai' '密三小区' 121.49911438083404 31.287004861188194 '2021' '11' '0'
#  4040000 80833 '49.98' '2' '1' '1' '1' 'Low' 'Plate       ' '1981 '
#  'Simplicity     ' 'Brick/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '光明·唐镇壹号' 121.48053886017651 31.235929042252014 '2021' '9' '0'
#  5150000 57159 '90.1' '2' '2' '0' '1' 'High' 'Plate       ' '2015 '
#  'Hardcover     ' 'Steel/Concrete  ' 'Yes           ' 'Unknown' 'Unknown']
# ['Shanghai' '杨镇新村' 121.60064563059096 31.22441717742983 '2021' '3' '0'
#  5630000 53330 '105.57' '3' '2' '1' '1' 'High' 'Plate       ' '1994 '
#  'Other     ' 'Brick/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '美林小城' 121.57001754490604 31.121330981865356 '2021' '25' '2'
#  5760000 60953 '94.5' '2' '2' '1' '1' 'Middle' 'Plate       ' '2006 '
#  'Hardcover     ' 'Steel/Concrete  ' 'Yes           ' 'Unknown' 'Unknown']
# ['Shanghai' '万寿新村(青浦)' 121.11756396632066 31.165263827867957 '2021' '4'
#  '6' 2030000 34797 '58.34' '2' '1' '1' '1' 'Low' 'Plate       ' '1994 '
#  'Simplicity     ' 'Brick/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '丰庄四村' 121.37620310061746 31.253747734417182 '2021' '35' '46'
#  3360000 49202 '68.29' '2' '1' '1' '1' 'High' 'Plate       ' '1996 '
#  'Simplicity     ' 'Brick/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '万荣小区' 121.4434830392455 31.291387910096027 '2021' '24' '28'
#  2130000 67066 '31.76' '1' '1' '1' '1' 'Middle' 'Plate       ' '1994 '
#  'Simplicity     ' 'Brick/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '振虹苑' 121.41607501949169 31.193255823927515 '2021' '3' '0'
#  7200000 88572 '81.29' '2' '2' '1' '1' 'Middle' 'Plate       ' '2005 '
#  'Simplicity     ' 'Steel/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '茂盛花苑' 121.3435277766753 31.175868591299583 '2021' '42' '39'
#  3260000 48832 '66.76' '2' '0' '1' '2' 'Middle' 'Plate       ' '1996 '
#  'Hardcover     ' 'Brick/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '延吉东路137弄' 121.55137761574345 31.299151281680984 '2021' '75'
#  '121' 1960000 60513 '32.39' '1' '0' '1' '1' 'High' 'Plate       ' '1991 '
#  'Hardcover     ' 'Brick/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '丽景新苑' 121.37021697236005 31.25004989790425 '2021' '29' '49'
#  5700000 52017 '109.58' '4' '2' '1' '2' 'High' 'Plate       ' '1998 '
#  'Hardcover     ' 'Steel/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '安西小区' 121.449013996101 31.245212845537495 '2021' '95' '65'
#  2400000 82249 '29.18' '1' '1' '1' '1' 'High' 'Plate       ' '1996 '
#  'Simplicity     ' 'Steel/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '华府天地愉园' 121.3639270371792 31.057520861599265 '2021' '132'
#  '59' 9500000 62092 '153' '4' '2' '1' '3' 'Middle' 'Plate       ' 'NaN '
#  'Hardcover     ' 'Steel/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '金盛佳苑' 121.69295460649079 31.248213080837292 '2021' '15' '0'
#  3490000 41993 '83.11' '2' '1' '1' '1' 'Middle' 'Plate       ' '2006 '
#  'Simplicity     ' 'Steel/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '听潮二村' 121.75053455239156 31.055674549371417 '2021' '4' '2'
#  1630000 28497 '57.2' '2' '1' '1' '1' 'Middle' 'Plate       ' '1989 '
#  'Hardcover     ' 'Brick/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '虹纺小区' 121.39558862335333 31.20800863413525 '2021' '114' '140'
#  3600000 72145 '49.9' '2' '0' '1' '1' 'Low' 'Plate       ' '1987 '
#  'Hardcover     ' 'Brick/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '奥林匹克花园' 121.33351301769731 31.153725893777253 '2021' '80'
#  '28' 4200000 54215 '77.47' '2' '2' '1' '1' 'Middle' 'Plate       '
#  '2003 ' 'Hardcover     ' 'Steel/Concrete  ' 'No           ' 'Unknown'
#  'Unknown']
# ['Shanghai' '欧五小区' 121.49386270716161 31.278979384559886 '2021' '208' '25'
#  2530000 82088 '30.76' '1' '0' '1' '1' 'Low' 'Plate       ' '1979 '
#  'Rough     ' 'Brick/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '广顺小区' 121.35912972643371 31.22227791813065 '2021' '6' '25'
#  3360000 60981 '55.1' '2' '1' '1' '1' 'High' 'Plate       ' '1998 '
#  'Hardcover     ' 'Brick/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '东亚阳光里' 121.81556567300592 30.91260647254807 '2021' '1' '0'
#  2360000 29829 '79.12' '2' '2' '1' '1' 'Middle' 'Plate       ' 'NaN '
#  'Hardcover     ' 'Steel/Concrete  ' 'Unknown           ' 'Unknown'
#  'Unknown']
# ['Shanghai' '当代万国府MOMA' 121.43585597631305 31.01642785820255 '2021' '89'
#  '39' 10600000 54107 '195.91' '4' '2' '1' '3' 'Low' 'Plate       ' '2015 '
#  'Rough     ' 'Steel/Concrete  ' 'Yes           ' 'Unknown' 'Unknown']
# ['Shanghai' '欣梅苑' 121.70858844609478 31.031920693080583 '2021' '26' '26'
#  2090000 22138 '94.32' '2' '2' '1' '1' 'Low' 'Plate       ' '2007 '
#  'Simplicity     ' 'Steel/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '爱都公寓' 121.3886278336176 31.19751322515359 '2021' '7' '19'
#  10460000 79775 '131.12' '3' '2' '1' '2' 'Middle' 'Plate & Tower       '
#  '1995 ' 'Hardcover     ' 'Steel/Concrete  ' 'Yes           ' 'Unknown'
#  'Unknown']
# ['Shanghai' '西湖苑' 121.3687300072494 31.119136891501313 '2021' '36' '30'
#  3380000 56588 '59.73' '2' '1' '1' '1' 'Low' 'Plate       ' '1995 '
#  'Hardcover     ' 'Brick/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '乐活居' 121.44536346216954 31.252292943816208 '2021' '9' '0'
#  8210000 117926 '69.62' '1' '2' '1' '1' 'High' 'Tower       ' '2011 '
#  'Hardcover     ' 'Steel  ' 'Yes           ' 'Unknown' 'Unknown']
# ['Shanghai' '杨泰三村' 121.44508687390304 31.38658724405351 '2021' '5' '9'
#  2730000 36467 '74.78' '2' '1' '1' '1' 'High' 'Plate       ' '1994 '
#  'Hardcover     ' 'Brick/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '虹桥宝龙城' 121.18970005470511 31.444703284783714 '2021' '8' '1'
#  3430000 42185 '81.19' '2' '2' '1' '1' 'Middle' 'Plate & Tower       '
#  '2015 ' 'Hardcover     ' 'Steel/Concrete  ' 'Yes           ' 'Unknown'
#  'Unknown']
# ['Shanghai' '幸福新苑' 121.45285299452844 31.309850865623865 '2021' '1' '0'
#  2040000 51000 '40' '1' '1' '1' '1' 'High' 'Plate       ' '1995 '
#  'Other     ' 'Brick/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '桃浦七村雪松苑' 121.35975386910204 31.29265918258936 '2021' '33'
#  '50' 2320000 46850 '49.52' '2' '0' '1' '1' 'Low' 'Plate       ' '1995 '
#  'Hardcover     ' 'Brick/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '桃浦二村永汇新苑' 121.3585310058113 31.28388289148988 '2021' '233'
#  '179' 5900000 46083 '128.03' '3' '2' '1' '2' 'Low' 'Plate       ' '2005 '
#  'Hardcover     ' 'Steel/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '清涧六街坊' 121.5807663991468 31.248636495879715 '2021' '12' '6'
#  4850000 64814 '74.83' '3' '1' '1' '1' 'Low' 'Plate       ' '1994 '
#  'Simplicity     ' 'Brick/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '大上海紫金城' 121.47361391283064 31.280223821863313 '2021' '7' '10'
#  8600000 95123 '90.41' '2' '2' '1' '1' 'Low' 'Plate       ' '2008 '
#  'Hardcover     ' 'Steel/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '长风二村长风馨苑' 121.40710472033015 31.2383267285194 '2021' '15'
#  '25' 3200000 78818 '40.6' '2' '0' '1' '1' 'Low' 'Plate       ' '1983 '
#  'Simplicity     ' 'Brick/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '凤城三村东区' 121.5279381300716 31.287819938399068 '2021' '29' '11'
#  1820000 57742 '31.52' '1' '0' '1' '1' 'Middle' 'Plate       ' '1988 '
#  'Simplicity     ' 'Brick/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '通河七村' 121.45834577339976 31.335453981011785 '2021' '37' '3'
#  4170000 51944 '80.28' '2' '1' '1' '1' 'Middle' 'Plate       ' '1995 '
#  'Simplicity     ' 'Brick/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '桃浦二村永汇新苑' 121.3585310058113 31.28388289148988 '2021' '32' '0'
#  4130000 51632 '79.99' '2' '2' '1' '1' 'High' 'Plate       ' '2003 '
#  'Other     ' 'Steel/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '林绿家园' 121.51897932922058 31.29606705478841 '2021' '3' '0'
#  6000000 85361 '70.29' '2' '1' '1' '1' 'High' 'Tower       ' '1990 '
#  'Simplicity     ' 'Steel/Concrete  ' 'Yes           ' 'Unknown' 'Unknown']
# ['Shanghai' '凤庆小区' 121.40787232238841 31.02126100141911 '2021' '48' '90'
#  1520000 35373 '42.83' '1' '1' '1' '1' 'High' 'Plate       ' '1988 '
#  'Hardcover     ' 'Brick/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '新凯城香樟苑' 121.23846750187751 31.118004817563207 '2021' '80'
#  '74' 2750000 40223 '68.37' '2' '1' '0' '1' 'High' 'Plate       ' '2011 '
#  'Simplicity     ' 'Steel/Concrete  ' 'Yes           ' 'Unknown' 'Unknown']
# ['Shanghai' '城东新村（二区）' 121.13059846910099 31.150502203332227 '2021' '73'
#  '113' 2400000 39159 '61.29' '3' '1' '1' '1' 'High' 'Plate       ' '1990 '
#  'Hardcover     ' 'Brick/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '听潮六村' 121.75034887264265 31.050578963716134 '2021' '77' '54'
#  2280000 28152 '80.99' '2' '2' '1' '1' 'High' 'Plate       ' '1994 '
#  'Simplicity     ' 'Brick/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '闸二小区' 121.53716597342286 31.335626859420838 '2021' '14' '6'
#  4000000 63583 '62.91' '2' '1' '0' '1' 'Middle' 'Plate       ' '1993 '
#  'Simplicity     ' 'Brick/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '明日星城（一期）' 121.50067276123275 31.219300784537676 '2021' '38'
#  '57' 15500000 127562 '121.51' '3' '2' '1' '2' 'High' 'Plate       '
#  '2002 ' 'Other     ' 'Steel/Concrete  ' 'Yes           ' 'Unknown'
#  'Unknown']
# ['Shanghai' '世盟壹天地' 121.32678650603862 31.297460608475667 '2021' '98' '4'
#  940000 25973 '36' '1' '1' '1' '1' 'Middle' 'Tower       ' '2014 '
#  'Other     ' 'Steel/Concrete  ' 'Yes           ' 'Unknown' 'Unknown']
# ['Shanghai' '沧州大楼' 121.46082150338525 31.232167278877895 '2021' '94' '40'
#  8150000 118305 '68.89' '2' '1' '1' '1' 'High' 'Plate       ' '1997 '
#  'Hardcover     ' 'Steel/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '紫薇新村' 121.30418999025731 31.208265139877536 '2021' '9' '21'
#  2690000 54509 '49.35' '1' '1' '1' '1' 'High' 'Plate       ' '2005 '
#  'Hardcover     ' 'Brick/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '海派青城' 121.32329901455722 31.072391817649166 '2021' '9' '9'
#  1680000 37728 '44.53' '1' '1' '1' '1' 'Middle' 'Plate       ' '2011 '
#  'Hardcover     ' 'Steel/Concrete  ' 'Yes           ' 'Unknown' 'Unknown']
# ['Shanghai' '法华镇路150弄' 121.44907822494497 31.22648559626562 '2021' '18'
#  '111' 5560000 101312 '54.88' '2' '1' '1' '1' 'High' 'Plate       '
#  '1981 ' 'Hardcover     ' 'Brick/Concrete  ' 'Yes           ' 'Unknown'
#  'Unknown']
# ['Shanghai' '虹桥1号' 121.3369687989942 31.230824703703952 '2021' '96' '137'
#  5390000 45935 '117.34' '3' '2' '1' '2' 'Low' 'Plate       ' 'NaN '
#  'Hardcover     ' 'Steel/Concrete  ' 'Unknown           ' 'Unknown'
#  'Unknown']
# ['Shanghai' '德州七村' 121.49219931484878 31.172185675499723 '2021' '10' '17'
#  2730000 62372 '43.69' '1' '1' '1' '1' 'Middle' 'Plate       ' '1992 '
#  'Simplicity     ' 'Brick/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '慈竹路70弄' 121.22670601968031 31.374330898000945 '2021' '51' '4'
#  2620000 31598 '82.76' '3' '1' '1' '1' 'Middle' 'Plate       ' 'NaN '
#  'Rough     ' 'Steel/Concrete  ' 'Yes           ' 'Unknown' 'Unknown']
# ['Shanghai' '明天华城' 121.58569980317705 31.10805931117418 '2021' '1' '0'
#  250000 13889 '18' 'NaN' ' ' ' ' ' ' '地下室' 'Plate       ' 'NaN '
#  'Other     ' 'Steel/Concrete  ' 'Unknown           ' 'Unknown' 'Unknown']
# ['Shanghai' '达安花园' 121.43649862407489 31.23773754036794 '2021' '26' '37'
#  12400000 121736 '101.86' '2' '2' '1' '2' 'High' 'Plate & Tower       '
#  '2004 ' 'Hardcover     ' 'Steel/Concrete  ' 'Yes           ' 'Unknown'
#  'Unknown']
# ['Shanghai' '西上海御庭' 121.21149492264931 31.293619472098847 '2021' '22' '0'
#  2740000 30327 '90.35' '2' '2' '1' '1' 'Low' 'Plate       ' 'NaN '
#  'Other     ' 'Steel/Concrete  ' 'Yes           ' 'Unknown' 'Unknown']
# ['Shanghai' '塘和家园桂花锦苑' 121.24638600696235 31.100244836291903 '2021' '71'
#  '12' 2720000 35528 '76.56' '2' '1' '1' '1' 'High' 'Plate       ' '2013 '
#  'Rough     ' 'Steel/Concrete  ' 'Yes           ' 'Unknown' 'Unknown']
# ['Shanghai' '凤城三村东区' 121.5279381300716 31.287819938399068 '2021' '16' '1'
#  2040000 68966 '29.58' '1' '0' '1' '1' 'High' 'Plate       ' '1988 '
#  'Other     ' 'Brick/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '丝庐花语' 121.47342796359007 31.20194278668469 '2021' '90' '218'
#  15120000 109312 '138.32' '3' '2' '1' '2' 'Middle' 'Plate       ' '2006 '
#  'Hardcover     ' 'Steel/Concrete  ' 'Yes           ' 'Unknown' 'Unknown']
# ['Shanghai' '虹南小区' 121.56147070696191 31.190437476987707 '2021' '95' '0'
#  2630000 68849 '38.2' '1' '1' '1' '1' 'High' 'Plate       ' '1985 '
#  'Hardcover     ' 'Steel/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '经纬观澜弘郡家园(三期)' 121.40430003086689 31.33318085455908 '2021'
#  '48' '24' 6200000 73495 '84.36' '2' '1' '1' '1' 'Middle' 'Plate       '
#  '2009 ' 'Hardcover     ' 'Steel/Concrete  ' 'Yes           ' 'Unknown'
#  'Unknown']
# ['Shanghai' '冠生园路247号—253号' 121.43249712218069 31.169320038318208 '2021'
#  '41' '19' 3350000 89073 '37.61' '1' '1' '1' '1' 'Low' 'Plate       '
#  '1992 ' 'Hardcover     ' 'Brick/Concrete  ' 'No           ' 'Unknown'
#  'Unknown']
# ['Shanghai' '罗马花园' 121.40195123144994 31.19908292411173 '2021' '20' '27'
#  11150000 73356 '152' '3' '2' '1' '2' 'Low' 'Plate       ' '1994 '
#  'Hardcover     ' 'Steel/Concrete  ' 'Yes           ' 'Unknown' 'Unknown']
# ['Shanghai' '九城湖滨国际' 121.32536152400813 31.15572896854691 '2021' '118'
#  '60' 5730000 56627 '101.19' '3' '2' '1' '1' 'Middle' 'Plate       '
#  '2007 ' 'Hardcover     ' 'Steel/Concrete  ' 'Yes           ' 'Unknown'
#  'Unknown']
# ['Shanghai' '新华小区（龙吴路5599弄）' 121.47442095050081 31.044616877687368 '2021'
#  '67' '34' 3390000 41671 '81.28' '2' '1' '1' '1' 'High' 'Plate       '
#  '1994 ' 'Simplicity     ' 'Brick/Concrete  ' 'No           ' 'Unknown'
#  'Unknown']
# ['Shanghai' '银河新都' 121.42009287054616 31.100552424717545 '2021' '29' '8'
#  3280000 64314 '51' '1' '1' '1' '1' 'Middle' 'Plate       ' '2007 '
#  'Simplicity     ' 'Steel/Concrete  ' 'Yes           ' 'Unknown' 'Unknown']
# ['Shanghai' '安居锦竹苑' 121.35423378174323 31.296172584519915 '2021' '15' '11'
#  3800000 49383 '76.95' '2' '1' '1' '1' 'Middle' 'Plate       ' '2013 '
#  'Simplicity     ' 'Steel/Concrete  ' 'Yes           ' 'Unknown' 'Unknown']
# ['Shanghai' '桃园新城中城苑' 121.5943530903241 31.095141921992063 '2021' '95'
#  '37' 4260000 46360 '91.89' '3' '1' '1' '1' 'Middle' 'Plate       '
#  '2006 ' 'Simplicity     ' 'Steel/Concrete  ' 'No           ' 'Unknown'
#  'Unknown']
# ['Shanghai' '盛世豪园(一期)' 121.52402699771172 31.323964867336414 '2021' '42'
#  '0' 8650000 90472 '95.61' '2' '1' '1' '1' 'Low' 'Plate       ' '2007 '
#  'Hardcover     ' 'Steel/Concrete  ' 'Yes           ' 'Unknown' 'Unknown']
# ['Shanghai' '航华四村' 121.36573954820668 31.17761120580383 '2021' '23' '108'
#  2320000 56975 '40.72' '1' '1' '1' '1' 'High' 'Plate       ' '1996 '
#  'Hardcover     ' 'Brick/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '明天华城' 121.58569980317705 31.10805931117418 '2021' '65' '23'
#  6400000 72481 '88.3' '2' '2' '1' '1' 'High' 'Plate       ' '2012 '
#  'Hardcover     ' 'Steel/Concrete  ' 'Yes           ' 'Unknown' 'Unknown']
# ['Shanghai' '殷行路470弄' 121.54184488750212 31.33545328703001 '2021' '6' '0'
#  4340000 61110 '71.02' '2' '1' '1' '1' 'Middle' 'Plate       ' '1994 '
#  'Rough     ' 'Brick/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '大木小区' 121.46937597692623 31.205724837255218 '2021' '38' '45'
#  5530000 102275 '54.07' '2' '1' '1' '1' 'High' 'Plate       ' '1985 '
#  'Hardcover     ' 'Brick/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '阳光威尼斯AB区' 121.37857390851939 31.26768471558547 '2021' '1' '0'
#  300000 10345 '29' 'NaN' ' ' ' ' ' ' '地下室' 'Plate       ' 'NaN '
#  'Other     ' 'Steel/Concrete  ' 'Unknown           ' 'Unknown' 'Unknown']
# ['Shanghai' '宝钢又一村' 121.5187640952204 31.27250301236876 '2021' '6' '9'
#  8600000 88423 '97.26' '2' '2' '1' '1' 'Low' 'Plate       ' '1997 '
#  'Simplicity     ' 'Brick/Concrete  ' 'Yes           ' 'Unknown' 'Unknown']
# ['Shanghai' '天平路36弄' 121.48053886017651 31.235929042252014 '2021' '23' '1'
#  6470000 149458 '43.29' '1' '1' '1' '1' 'Middle' 'Plate       ' '1977 '
#  'Hardcover     ' 'Brick/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '富丽苑' 121.37263053960426 31.395522934561118 '2021' '60' '78'
#  3350000 35249 '95.04' '3' '1' '1' '1' 'Low' 'Plate       ' '2005 '
#  'Hardcover     ' 'Steel/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '曹杨三村(杏杨园)' 121.40908781957397 31.2428394949006 '2021' '10'
#  '9' 2490000 82122 '30.26' '1' '1' '1' '1' 'High' 'Plate       ' '1982 '
#  'Hardcover     ' 'Brick/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '江南新村(徐汇)' 121.4692980938385 31.1984113244461 '2021' '51' '20'
#  2180000 77333 '28.19' '1' '1' '1' '1' 'Middle' 'Plate       ' '1966 '
#  'Simplicity     ' 'Brick/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '东二小区' 121.60283686722144 31.274353317973127 '2021' '40' '10'
#  3790000 56720 '66.82' '2' '1' '1' '1' 'High' 'Plate       ' '1996 '
#  'Hardcover     ' 'Brick/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '解放新村' 121.45984199105717 30.91896384361939 '2021' '22' '9'
#  870000 22510 '38.65' '1' '1' '1' '1' 'Middle' 'Plate       ' '1979 '
#  'Simplicity     ' 'Brick/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '西凌新邨' 121.49307516272101 31.21097168820248 '2021' '127' '61'
#  2800000 108150 '25.89' '1' '0' '1' '1' 'High' 'Plate       ' '1987 '
#  'Hardcover     ' 'Brick/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '金地未未来' 121.59413291564361 31.312679112412628 '2021' '127'
#  '20' 9900000 110590 '89.52' '4' '2' '1' '2' 'Middle' 'Plate       '
#  '2009 ' 'Hardcover     ' 'Steel/Concrete  ' 'Yes           ' 'Unknown'
#  'Unknown']
# ['Shanghai' '潼港二村' 121.58108781285827 31.345741846928753 '2021' '7' '15'
#  1940000 42167 '45.89' '1' '1' '1' '1' 'Middle' 'Plate       ' '1994 '
#  'Simplicity     ' 'Brick/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '翠竹苑' 121.36406645419434 31.219269439284236 '2021' '73' '200'
#  4770000 61343 '77.76' '3' '2' '1' '1' 'Middle' 'Plate       ' '1997 '
#  'Hardcover     ' 'Brick/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '浦江东旭公寓(669弄1-109号)' 121.59285435741126 31.29954245329162
#  '2021' '39' '16' 5820000 65867 '88.36' '3' '2' '1' '1' 'High'
#  'Plate       ' '2007 ' 'Hardcover     ' 'Steel/Concrete  '
#  'Yes           ' 'Unknown' 'Unknown']
# ['Shanghai' '乐山四五村' 121.43873486581143 31.20323434875948 '2021' '64' '19'
#  4690000 127239 '36.86' '1' '0' '1' '1' 'Middle' 'Plate       ' '1990 '
#  'Hardcover     ' 'Brick/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '明天华城' 121.58569980317705 31.10805931117418 '2021' '60' '34'
#  5680000 63821 '89' '2' '2' '1' '1' 'Low' 'Plate       ' '2011 '
#  'Hardcover     ' 'Steel/Concrete  ' 'Yes           ' 'Unknown' 'Unknown']
# ['Shanghai' '南苑十村' 121.25518041790504 31.371773220186217 '2021' '46' '17'
#  2380000 27009 '88.12' '2' '1' '1' '1' 'High' 'Plate       ' '1999 '
#  'Simplicity     ' 'Brick/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '瞿溪新村' 121.501622629479 31.21177561519678 '2021' '127' '172'
#  2580000 92673 '27.84' '1' '1' '1' '1' 'Middle' 'Plate       ' '1964 '
#  'Simplicity     ' 'Brick/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '曹杨五村(南岭园)' 121.41561912944537 31.241076404257626 '2021' '86'
#  '101' 5050000 83804 '60.26' '3' '1' '1' '1' 'Low' 'Plate       ' '1993 '
#  'Hardcover     ' 'Brick/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '瑞虹新城天悦郡庭' 121.5069355675872 31.273976315392403 '2021' '68'
#  '2' 25500000 149350 '170.74' '3' '2' '1' '2' 'Middle' 'Plate       '
#  '2020 ' 'Hardcover     ' 'Steel/Concrete  ' 'Yes           ' 'Unknown'
#  'Unknown']
# ['Shanghai' '新湖青蓝国际' 121.48022310578976 31.26889882355579 '2021' '47'
#  '108' 17400000 121111 '143.67' '3' '2' '1' '2' 'High' 'Plate       '
#  '2017 ' 'Hardcover     ' 'Steel/Concrete  ' 'Yes           ' 'Unknown'
#  'Unknown']
# ['Shanghai' '菊泉新城(菊泉街39弄)' 121.38705418202522 31.35767887166241 '2021' '6'
#  '21' 2510000 46248 '54.23' '1' '1' '1' '1' 'Low' 'Plate & Tower       '
#  '2005 ' 'Hardcover     ' 'Steel/Concrete  ' 'No           ' 'Unknown'
#  'Unknown']
# ['Shanghai' '平型关路255弄' 121.47234838002818 31.275906450707378 '2021' '19'
#  '0' 2020000 69440 '29.09' '1' '0' '1' '1' 'High' 'Plate       ' '1988 '
#  'Simplicity     ' 'Brick/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '浦发香舍(公寓)' 121.72044598899593 31.146791867059758 '2021' '78'
#  '101' 2220000 34656 '64.06' '2' '1' '1' '1' 'Low' 'Plate       ' '2008 '
#  'Simplicity     ' 'Steel/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '昌鑫家园' 121.45569298739824 31.333971855494866 '2021' '63' '35'
#  5580000 61339 '90.97' '2' '2' '1' '1' 'Low' 'Plate       ' '2000 '
#  'Simplicity     ' 'Steel/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '新凯二期' 121.24540802175363 31.1128965656244 '2021' '66' '128'
#  3400000 41893 '81.16' '2' '2' '1' '1' 'Middle' 'Plate       ' '2009 '
#  'Hardcover     ' 'Steel/Concrete  ' 'Yes           ' 'Unknown' 'Unknown']
# ['Shanghai' '嘉富小区' 121.26231871280952 31.401507555195458 '2021' '27' '14'
#  2000000 28277 '70.73' '2' '1' '1' '1' 'High' 'Plate       ' '1994 '
#  'Simplicity     ' 'Brick/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '万科琥珀郡园' 121.36679559616421 31.39687285019796 '2021' '84' '47'
#  4300000 54075 '79.52' '3' '2' '1' '1' 'Middle' 'Plate       ' '2010 '
#  'Hardcover     ' 'Steel/Concrete  ' 'Yes           ' 'Unknown' 'Unknown']
# ['Shanghai' '紫荆四村' 121.17141765113549 31.29850577936977 '2021' '21' '0'
#  2910000 23619 '123.21' '3' '1' '1' '2' 'Middle' 'Plate       ' '1999 '
#  'Simplicity     ' 'Brick/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '爱中爱华公寓' 121.45582387051104 31.19238833443246 '2021' '14' '16'
#  6200000 69624 '89.05' '1' '2' '1' '1' 'Low' 'Tower       ' '1997 '
#  'Hardcover     ' 'Steel/Concrete  ' 'Yes           ' 'Unknown' 'Unknown']
# ['Shanghai' '贝尚湾(公寓)' 121.32635055837461 31.152416265987686 '2021' '93'
#  '82' 7630000 57655 '132.34' '3' '2' '1' '2' 'Low' 'Plate       ' '2009 '
#  'Hardcover     ' 'Steel/Concrete  ' 'Yes           ' 'Unknown' 'Unknown']
# ['Shanghai' '上海派' 121.2005962310495 31.29573364793739 '2021' '3' '1'
#  3480000 39868 '87.29' '3' '2' '1' '1' 'Middle' 'Plate       ' 'NaN '
#  'Hardcover     ' 'Steel/Concrete  ' 'Yes           ' 'Unknown' 'Unknown']
# ['Shanghai' '南苑五村' 121.25680644070866 31.374710423865903 '2021' '24' '7'
#  2110000 26422 '79.86' '2' '1' '0' '1' 'High' 'Plate       ' '1995 '
#  'Simplicity     ' 'Brick/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '学北路20弄' 121.71138639826671 31.195721248087228 '2021' '96'
#  '58' 2950000 36420 '81' '2' '1' '1' '1' 'High' 'Plate       ' '1997 '
#  'Simplicity     ' 'Mixed  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '中星海上名豪苑(三期)' 121.33632525292686 31.272041201855934 '2021'
#  '11' '15' 4700000 53391 '88.03' '2' '1' '1' '1' 'Low' 'Plate       '
#  '2012 ' 'Simplicity     ' 'Steel/Concrete  ' 'Yes           ' 'Unknown'
#  'Unknown']
# ['Shanghai' '中意小区' 121.42785997930763 31.216331894664496 '2021' '79' '74'
#  1350000 69302 '19.48' '1' '0' '1' '1' 'Low' 'Other       ' 'NaN '
#  'Simplicity     ' 'Unknown  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '丰庄十四街坊' 121.48053886017651 31.235929042252014 '2021' '3' '18'
#  3180000 51843 '61.34' '2' '1' '1' '1' 'High' 'Plate       ' '1998 '
#  'Simplicity     ' 'Brick/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '汇丽苑' 121.59476379560327 31.12887113939111 '2021' '50' '54'
#  3700000 46810 '78.98' '2' '2' '1' '1' 'High' 'Plate       ' '2006 '
#  'Hardcover     ' 'Steel/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '缘圆宝邸' 121.32466704401835 31.24839484235998 '2021' '8' '23'
#  4350000 59663 '72.91' '2' '1' '1' '1' 'Middle' 'Plate       ' '2008 '
#  'Hardcover     ' 'Steel/Concrete  ' 'Yes           ' 'Unknown' 'Unknown']
# ['Shanghai' '西上海名邸' 121.17446829664739 31.293254967483577 '2021' '7' '6'
#  3230000 36325 '88.92' '2' '2' '1' '1' 'Middle' 'Plate       ' '2011 '
#  'Hardcover     ' 'Steel/Concrete  ' 'Yes           ' 'Unknown' 'Unknown']
# ['Shanghai' '众旺苑' 121.44804301767526 30.918382876667124 '2021' '415' '121'
#  2500000 28882 '86.56' '2' '2' '1' '1' 'Low' 'Plate       ' '2013 '
#  'Hardcover     ' 'Steel/Concrete  ' 'Yes           ' 'Unknown' 'Unknown']
# ['Shanghai' '融信铂爵' 121.08563504442677 31.141839836254448 '2021' '127' '44'
#  5760000 53334 '108' '3' '2' '1' '2' 'Low' 'Plate       ' 'NaN '
#  'Hardcover     ' 'Steel/Concrete  ' 'Yes           ' 'Unknown' 'Unknown']
# ['Shanghai' '高行家园' 121.62008253640201 31.30076702350573 '2021' '4' '1'
#  5180000 63357 '81.76' '2' '2' '1' '1' 'Middle' 'Plate       ' '2008 '
#  'Hardcover     ' 'Steel/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '绿地东岸涟城' 121.9233493087734 30.890324694600853 '2021' '12' '10'
#  2200000 41691 '52.77' '1' '1' '1' '1' 'Low' 'Plate       ' '2009 '
#  'Hardcover     ' 'Steel/Concrete  ' 'Yes           ' 'Unknown' 'Unknown']
# ['Shanghai' '紫阳花苑' 121.46058147615298 31.120005367577285 '2021' '14' '12'
#  4730000 76058 '62.19' '2' '1' '1' '1' 'Low' 'Plate       ' '1996 '
#  'Hardcover     ' 'Mixed  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '莲溪六村' 121.56566040386045 31.193483178521433 '2021' '59' '27'
#  3920000 64023 '61.15' '2' '1' '1' '1' 'Middle' 'Plate       ' '1994 '
#  'Simplicity     ' 'Brick/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '德州二村' 121.49892681464355 31.17427115978316 '2021' '25' '20'
#  2270000 69018 '32.89' '1' '0' '1' '1' 'Low' 'Plate       ' '1984 '
#  'Simplicity     ' 'Brick/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '运光小区' 121.50248697904071 31.2956889056039 '2021' '6' '2'
#  3400000 78814 '43.14' '1' '1' '1' '1' 'High' 'Plate       ' '1987 '
#  'Simplicity     ' 'Brick/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '万科金色城市' 121.57868789985781 31.167255300879095 '2021' '45'
#  '82' 8880000 113803 '78.03' '3' '2' '1' '1' 'Low' 'Plate       ' '2010 '
#  'Hardcover     ' 'Steel/Concrete  ' 'Yes           ' 'Unknown' 'Unknown']
# ['Shanghai' '畅馨园' 121.42290798035332 31.030078520945512 '2021' '97' '33'
#  6480000 48995 '132.26' '3' '2' '1' '2' 'Low' 'Plate       ' '2007 '
#  'Simplicity     ' 'Steel/Concrete  ' 'Yes           ' 'Unknown' 'Unknown']
# ['Shanghai' '金枫公寓' 121.68919537759263 31.245412751016584 '2021' '116' '0'
#  3630000 38405 '94.39' '2' '2' '1' '1' 'Low' 'Plate       ' '2004 '
#  'Simplicity     ' 'Steel/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '南苑十村' 121.25518041790504 31.371773220186217 '2021' '20' '8'
# ...
# ['Shanghai' '唐家沙小区' 121.47225342913578 31.27690001310791 '2021' '12' '39'
#  2500000 60592 '41.26' '2' '0' '1' '1' 'High' 'Plate       ' '1985 '
#  'Hardcover     ' 'Brick/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '和润家园(别墅)' 121.3663897417348 31.095110148699764 '2021' '97'
#  '86' 18000000 92861 '193.84' '4' '2' '1' '3' 'Low' 'Plate       ' '2004 '
#  'Hardcover     ' 'Steel/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '水清嘉苑' 121.38780380833448 31.122766684977247 '2021' '8' '5'
#  5770000 76811 '75.12' '1' '2' '1' '1' 'High' 'Plate       ' '2011 '
#  'Hardcover     ' 'Steel/Concrete  ' 'Yes           ' 'Unknown' 'Unknown']
# ['Shanghai' '上工新村' 121.46015514035795 31.281061873030396 '2021' '54' '17'
#  2610000 93645 '27.85' '1' '0' '1' '1' 'Middle' 'Plate       ' '1995 '
#  'Simplicity     ' 'Brick/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '菊泉新城(陆翔路678弄)' 121.3754552612804 31.358158605779572 '2021'
#  '1' '0' 3130000 40129 '78' '2' '1' '1' '1' 'High' 'Plate       ' '2005 '
#  'Other     ' 'Steel/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '水电新村' 121.33840213526592 31.835599975365863 '2021' '68' '92'
#  3500000 51043 '68.57' '2' '1' '1' '1' 'High' 'Plate       ' '1997 '
#  'Hardcover     ' 'Brick/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '黎安一村（北区）' 121.37660239741663 31.13544546561599 '2021' '12'
#  '22' 2700000 57841 '46.68' '1' '1' '1' '1' 'High' 'Plate       ' '1994 '
#  'Hardcover     ' 'Brick/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '未来域' 121.4268805568101 31.1837669073827 '2021' '74' '71'
#  8280000 88283 '93.79' '2' '2' '1' '1' 'High' 'Plate       ' '2006 '
#  'Hardcover     ' 'Steel/Concrete  ' 'Yes           ' 'Unknown' 'Unknown']
# ['Shanghai' '浦南园' 121.47973891911988 30.9107293635874 '2021' '33' '0'
#  3100000 24543 '126.31' '3' '2' '1' '2' 'Middle' 'Plate       ' '2005 '
#  'Simplicity     ' 'Steel/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '美罗家园宝欣苑六村' 121.34503603162656 31.388810130576182 '2021' '48'
#  '21' 2200000 32033 '68.68' '2' '1' '1' '1' 'Low' 'Plate       ' 'NaN '
#  'Rough     ' 'Steel/Concrete  ' 'Yes           ' 'Unknown' 'Unknown']
# ['Shanghai' '梦景苑' 121.41558984468574 31.132887348161336 '2021' '21' '0'
#  8650000 84177 '102.76' '2' '2' '1' '1' 'Middle' 'Plate       ' '2004 '
#  'Simplicity     ' 'Steel/Concrete  ' 'Yes           ' 'Unknown' 'Unknown']
# ['Shanghai' '朗诗未来街区' 121.51472836788626 30.975867534687428 '2021' '22'
#  '16' 2830000 36465 '77.61' '3' '1' '1' '1' 'Middle' 'Plate       ' 'NaN '
#  'Hardcover     ' 'Steel/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '远洋香奈' 121.4360040170611 31.40135606617223 '2021' '19' '9'
#  5400000 55103 '98' '2' '2' '1' '1' 'High' 'Plate       ' '2014 '
#  'Hardcover     ' 'Steel/Concrete  ' 'Yes           ' 'Unknown' 'Unknown']
# ['Shanghai' '富锦路1659弄' 121.44594439634285 31.410876817729207 '2021' '190'
#  '45' 2140000 31550 '67.83' '2' '1' '1' '1' 'High' 'Plate       ' '1995 '
#  'Rough     ' 'Brick/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '闸园新村' 121.4401591291975 31.00138579686845 '2021' '309' '99'
#  2030000 25199 '80.56' '3' '1' '1' '1' 'Middle' 'Plate       ' '1993 '
#  'Hardcover     ' 'Brick/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '航华四村' 121.36573954820668 31.17761120580383 '2021' '32' '27'
#  3010000 57730 '52.14' '2' '1' '1' '1' 'Middle' 'Plate       ' '1994 '
#  'Simplicity     ' 'Brick/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '清涧三街坊' 121.39310786285698 31.267111377050355 '2021' '54' '12'
#  2820000 50629 '55.7' '1' '1' '1' '1' 'High' 'Plate       ' '2000 '
#  'Simplicity     ' 'Brick/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '新城尚上城' 121.18665956004548 31.290718593098298 '2021' '6' '11'
#  2980000 35723 '83.28' '2' '2' '0' '1' 'Low' 'Plate       ' '2013 '
#  'Hardcover     ' 'Steel/Concrete  ' 'Yes           ' 'Unknown' 'Unknown']
# ['Shanghai' '玉兰香苑(四期)' 121.64488466170195 31.20671374041808 '2021' '11'
#  '0' 4010000 64814 '61.87' '1' '2' '1' '1' 'Low' 'Tower       ' '2008 '
#  'Simplicity     ' 'Steel/Concrete  ' 'Yes           ' 'Unknown' 'Unknown']
# ['Shanghai' '海派青城' 121.32329901455722 31.072391817649166 '2021' '42' '18'
#  3340000 36463 '91.6' '2' '1' '1' '1' 'Low' 'Plate       ' '2009 '
#  'Simplicity     ' 'Steel/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '仙逸小区' 121.39820377035397 31.212993383125085 '2021' '15' '33'
#  2970000 74887 '39.66' '1' '1' '1' '1' 'Low' 'Plate       ' '1990 '
#  'Hardcover     ' 'Brick/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '淞南大八村' 121.49634993545764 31.353721645447727 '2021' '2' '0'
#  4050000 50740 '79.82' '3' '2' '1' '1' 'Low' 'Plate       ' '1994 '
#  'Rough     ' 'Brick/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '崧泽华城佳福雅苑（五区）' 121.16280299112535 31.160724841787278 '2021'
#  '12' '12' 3290000 42083 '78.18' '2' '1' '1' '1' 'Middle' 'Plate       '
#  '2014 ' 'Hardcover     ' 'Steel/Concrete  ' 'Yes           ' 'Unknown'
#  'Unknown']
# ['Shanghai' '华夏小区' 121.50061967137711 31.16876100562306 '2021' '23' '60'
#  2160000 62938 '34.32' '1' '1' '1' '1' 'High' 'Plate       ' '1996 '
#  'Hardcover     ' 'Brick/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '海华花园' 121.47554266459112 31.210392210997142 '2021' '36' '21'
#  13100000 113696 '115.22' '3' '2' '1' '2' 'Low' 'Plate & Tower       '
#  '1994 ' 'Simplicity     ' 'Steel/Concrete  ' 'Yes           ' 'Unknown'
#  'Unknown']
# ['Shanghai' '鞍山四村第三小区' 121.51440291180002 31.28119627530728 '2021' '68'
#  '18' 2210000 72248 '30.52' '1' '0' '1' '1' 'Middle' 'Plate       '
#  '1968 ' 'Hardcover     ' 'Steel/Concrete  ' 'No           ' 'Unknown'
#  'Unknown']
# ['Shanghai' '航华一村' 121.35806200050455 31.180690381526052 '2021' '20' '6'
#  2480000 60681 '40.87' '1' '1' '0' '1' 'Middle' 'Plate       ' '1994 '
#  'Simplicity     ' 'Brick/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '范东铁路小区' 121.4211589795254 31.225398857966976 '2021' '305'
#  '239' 3450000 78606 '43.89' '1' '1' '1' '1' 'Low' 'Plate       ' '1996 '
#  'Hardcover     ' 'Brick/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '蒲汇新村' 121.36408127623527 31.16213578575652 '2021' '61' '18'
#  5800000 85723 '67.66' '2' '1' '1' '1' 'Low' 'Plate       ' '1994 '
#  'Simplicity     ' 'Brick/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '骏华苑' 121.41841869856721 31.305869007863595 '2021' '4' '2'
#  2880000 54587 '52.76' '1' '1' '1' '1' 'High' 'Plate       ' '2008 '
#  'Rough     ' 'Steel/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '高南新村' 121.5907248343693 31.34680852721839 '2021' '30' '9'
#  3620000 41662 '86.89' '3' '1' '1' '1' 'Low' 'Plate       ' '1993 '
#  'Simplicity     ' 'Brick/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '金杨二街坊' 121.58139341639276 31.25520188497497 '2021' '17' '0'
#  4190000 72479 '57.81' '2' '1' '1' '1' 'Middle' 'Plate       ' '1995 '
#  'Hardcover     ' 'Brick/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '园南一村' 121.44600018111502 31.147062988805903 '2021' '19' '13'
#  5350000 101905 '52.5' '2' '1' '1' '1' 'Middle' 'Plate       ' '1988 '
#  'Simplicity     ' 'Brick/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '达城锦园' 121.60889494975018 31.12533507051341 '2021' '16' '7'
#  2630000 48019 '54.77' '1' '1' '1' '1' 'Middle' 'Plate       ' '2010 '
#  'Hardcover     ' 'Steel/Concrete  ' 'Yes           ' 'Unknown' 'Unknown']
# ['Shanghai' '万业紫辰苑' 121.44469898558383 31.405662080085595 '2021' '22' '22'
#  4010000 47088 '85.16' '2' '2' '1' '1' 'Low' 'Plate       ' 'NaN '
#  'Hardcover     ' 'Steel/Concrete  ' 'Yes           ' 'Unknown' 'Unknown']
# ['Shanghai' '临沂八村' 121.52337392960597 31.20210077735759 '2021' '20' '10'
#  2550000 64639 '39.45' '1' '1' '1' '1' 'High' 'Plate       ' '1989 '
#  'Hardcover     ' 'Brick/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '南苑七村' 121.25718193241181 31.372756049520923 '2021' '211' '84'
#  1760000 25252 '69.7' '2' '1' '1' '1' 'High' 'Plate       ' '1996 '
#  'Hardcover     ' 'Brick/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '金厦苑' 121.69942851464009 31.193460242298354 '2021' '25' '21'
#  4140000 53496 '77.39' '2' '2' '1' '1' 'High' 'Plate       ' '1999 '
#  'Rough     ' 'Steel/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '共康五村' 121.44276574229579 31.32947744970655 '2021' '8' '35'
#  2500000 47917 '52.07' '1' '1' '1' '1' 'High' 'Plate       ' '1994 '
#  'Hardcover     ' 'Brick/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '德州二村' 121.49917986730571 31.173777272107746 '2021' '1' '0'
#  2900000 69679 '41.62' '1' '1' '1' '1' 'Middle' 'Plate       ' '1984 '
#  'Simplicity     ' 'Brick/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '海尚墅林苑' 121.51640110257641 30.843916373376256 '2021' '139'
#  '17' 1300000 18157 '71.6' '1' '1' '1' '1' 'Middle' 'Plate       ' '2011 '
#  'Hardcover     ' 'Steel/Concrete  ' 'Yes           ' 'Unknown' 'Unknown']
# ['Shanghai' '富浩河滨花园' 121.43129941144423 31.41221472240116 '2021' '54' '11'
#  3850000 39769 '96.81' '2' '2' '1' '1' 'Middle' 'Plate       ' '2006 '
#  'Hardcover     ' 'Steel/Concrete  ' 'Yes           ' 'Unknown' 'Unknown']
# ['Shanghai' '经纬观澜弘郡家园(三期)' 121.40430003086689 31.33318085455908 '2021'
#  '99' '27' 4520000 70198 '64.39' '1' '1' '1' '1' 'High' 'Plate       '
#  '2009 ' 'Simplicity     ' 'Steel/Concrete  ' 'Yes           ' 'Unknown'
#  'Unknown']
# ['Shanghai' '海滨八村' 121.50523830915667 31.387672799837585 '2021' '71' '16'
#  2150000 42432 '50.67' '2' '1' '1' '1' 'High' 'Plate       ' '1994 '
#  'Simplicity     ' 'Brick/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '宁怡苑' 121.61833326608242 31.144490120836252 '2021' '58' '44'
#  4310000 40060 '107.59' '2' '2' '1' '2' 'Middle' 'Plate       ' '2006 '
#  'Simplicity     ' 'Steel/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '听潮四村' 121.75032318110505 31.052988349108322 '2021' '75' '45'
#  1610000 28633 '56.23' '2' '1' '0' '1' 'High' 'Plate       ' '1994 '
#  'Simplicity     ' 'Brick/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '瑞阳苑' 121.59414495293744 31.105419052454817 '2021' '62' '1'
#  2660000 44349 '59.98' '1' '1' '1' '1' 'Low' 'Plate       ' '2007 '
#  'Simplicity     ' 'Steel/Concrete  ' 'Yes           ' 'Unknown' 'Unknown']
# ['Shanghai' '巨龙台湾城' 121.4387242658064 30.989863821940144 '2021' '2' '0'
#  940000 28589 '32.88' '1' '1' '1' '1' 'High' 'Plate       ' 'NaN '
#  'Simplicity     ' 'Brick/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '思浦小区' 121.50015946946435 31.164910255877725 '2021' '9' '12'
#  2380000 64957 '36.64' '1' '0' '0' '1' 'High' 'Plate       ' '1986 '
#  'Simplicity     ' 'Brick/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '罗阳七村(华宝小区)' 121.40722033224928 31.127690764382614 '2021' '13'
#  '13' 3170000 60347 '52.53' '1' '1' '1' '1' 'High' 'Plate       ' '1996 '
#  'Simplicity     ' 'Brick/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '九歌花园' 121.38765568739471 31.165375994189862 '2021' '26' '30'
#  3600000 79876 '45.07' '1' '1' '0' '1' 'High' 'Tower       ' '2008 '
#  'Hardcover     ' 'Steel/Concrete  ' 'Yes           ' 'Unknown' 'Unknown']
# ['Shanghai' '鸿艺豪苑' 121.45213066706786 31.21576750618642 '2021' '22' '23'
#  15280000 134745 '113.4' '1' '2' '1' '2' 'High' 'Tower       ' '2000 '
#  'Hardcover     ' 'Steel/Concrete  ' 'Yes           ' 'Unknown' 'Unknown']
# ['Shanghai' '光复西路南林家港小区' 121.42323110084527 31.23707200724686 '2021' '205'
#  '84' 1950000 66599 '29.28' '1' '1' '1' '1' 'High' 'Plate       ' '1987 '
#  'Simplicity     ' 'Mixed  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '大华一村' 121.42828335069449 31.27971020125982 '2021' '41' '19'
#  2610000 56504 '46.13' '1' '1' '1' '1' 'High' 'Plate       ' '1994 '
#  'Simplicity     ' 'Brick/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '珠江玫瑰花园(公寓)' 121.53848037404506 31.24903135221917 '2021' '42'
#  '0' 16200000 96314 '168.2' '3' '2' '0' '2' 'High' 'Tower       ' '1998 '
#  'Hardcover     ' 'Steel/Concrete  ' 'Yes           ' 'Unknown' 'Unknown']
# ['Shanghai' '杉林新月环林东路879弄' 121.5352303945405 31.145038094542038 '2021'
#  '19' '0' 3320000 64155 '51.75' '1' '1' '1' '1' 'Low' 'Plate       '
#  '2004 ' 'Simplicity     ' 'Steel/Concrete  ' 'No           ' 'Unknown'
#  'Unknown']
# ['Shanghai' '世盟壹天地' 121.32678650603862 31.297460608475667 '2021' '52' '0'
#  1300000 22672 '57.34' '1' '1' '1' '1' 'High' 'Tower       ' '2014 '
#  'Other     ' 'Steel/Concrete  ' 'Yes           ' 'Unknown' 'Unknown']
# ['Shanghai' '航欣苑' 121.60016243205713 31.04254089140158 '2021' '134' '49'
#  5160000 41008 '125.83' '3' '2' '1' '1' 'Low' 'Plate       ' '2013 '
#  'Hardcover     ' 'Steel/Concrete  ' 'Yes           ' 'Unknown' 'Unknown']
# ['Shanghai' '白玉新村' 121.42169948995075 31.239023591360276 '2021' '14' '0'
#  3080000 82796 '37.2' '1' '1' '1' '1' 'Low' 'Plate       ' '1984 '
#  'Simplicity     ' 'Brick/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '工农四村星源佳苑' 121.54549236719483 31.3286947390095 '2021' '2' '0'
#  360000 12097 '29.76' 'NaN' ' ' ' ' ' ' '地下室' 'Other       ' 'NaN '
#  'Other     ' 'Unknown  ' 'Unknown           ' 'Unknown' 'Unknown']
# ['Shanghai' '欣乐苑（东苑）' 121.24390946850188 31.190426047118553 '2021' '42'
#  '132' 2340000 42059 '55.47' '1' '1' '1' '1' 'Low' 'Plate       ' '2013 '
#  'Hardcover     ' 'Steel/Concrete  ' 'Yes           ' 'Unknown' 'Unknown']
# ['Shanghai' '凌四小区' 121.55280484353771 31.254104366896478 '2021' '9' '0'
#  2980000 80781 '36.89' '1' '1' '1' '1' 'Low' 'Plate       ' '1987 '
#  'Hardcover     ' 'Brick/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '莱茵半岛' 121.54326672546331 31.314025216385588 '2021' '43' '42'
#  14150000 60427 '234.17' '5' '3' '1' '3' 'Low' 'Plate       ' '2002 '
#  'Hardcover     ' 'Steel/Concrete  ' 'Yes           ' 'Unknown' 'Unknown']
# ['Shanghai' '绿地康桥新苑' 121.56902842070902 31.143839687658442 '2021' '9' '0'
#  5660000 64209 '88.15' '3' '2' '1' '2' 'High' 'Plate       ' '2004 '
#  'Simplicity     ' 'Steel/Concrete  ' 'Yes           ' 'Unknown' 'Unknown']
# ['Shanghai' '香山新村东南街坊' 121.5782501555828 31.246908169374557 '2021' '16'
#  '18' 3590000 69151 '51.8' '2' '1' '1' '1' 'Middle' 'Plate       ' '1995 '
#  'Hardcover     ' 'Brick/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '绿地东上海三期' 121.57865241679016 31.132679088492672 '2021' '35'
#  '14' 6400000 69242 '92.43' '2' '2' '1' '1' 'Middle' 'Plate       '
#  '2014 ' 'Simplicity     ' 'Steel/Concrete  ' 'Yes           ' 'Unknown'
#  'Unknown']
# ['Shanghai' '梦丹苑' 121.13885012385454 31.15256460537255 '2021' '32' '18'
#  2520000 35167 '71.66' '2' '1' '1' '1' 'Middle' 'Plate       ' '1999 '
#  'Hardcover     ' 'Brick/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '金杨新村九街坊' 121.58821595691049 31.25970488503576 '2021' '77'
#  '10' 2680000 65303 '41.04' '1' '1' '1' '1' 'Middle' 'Plate       '
#  '1994 ' 'Simplicity     ' 'Brick/Concrete  ' 'No           ' 'Unknown'
#  'Unknown']
# ['Shanghai' '浦润苑' 121.53919225768 31.04823487984977 '2021' '12' '10'
#  4480000 41332 '108.27' '3' '2' '1' '1' 'Middle' 'Plate       ' '2012 '
#  'Hardcover     ' 'Steel/Concrete  ' 'Yes           ' 'Unknown' 'Unknown']
# ['Shanghai' '幸福小镇' 121.61572602417026 31.305599271425 '2021' '69' '23'
#  5420000 55104 '98.36' '2' '2' '1' '1' 'Low' 'Plate       ' '2006 '
#  'Simplicity     ' 'Steel/Concrete  ' 'Yes           ' 'Unknown' 'Unknown']
# ['Shanghai' '四平路2100弄' 121.51909826487011 31.299191239731783 '2021' '50'
#  '57' 2280000 66843 '34.11' '1' '1' '1' '1' 'High' 'Plate       ' '1988 '
#  'Hardcover     ' 'Brick/Concrete  ' 'No           ' 'Unknown' 'Unknown']
# ['Shanghai' '靖宇家园' 121.54892757729553 31.29823594450374 '2021' '55' '69'
#  9500000 96232 '98.72' '2' '2' '1' '1' 'High' 'Plate       ' '2011 '
#  'Hardcover     ' 'Steel/Concrete  ' 'Yes           ' 'Unknown' 'Unknown']
# ['Shanghai' '钦州公寓' 121.43411703650683 31.182074456063013 '2021' '62' '47'
#  6320000 81623 '77.43' '2' '1' '1' '1' 'Middle' 'Plate & Tower       '
#  '1996 ' 'Simplicity     ' 'Steel/Concrete  ' 'Yes           ' 'Unknown'
#  'Unknown']

# %%
# Saving File
beijing.to_csv('../Resources/Beijing Deals Information (Cleaned).csv')
shanghai.to_csv('../Resources/Shanghai Deals Information (Cleaned).csv')

# %%
# To SQL
db_string = f"postgres://postgres:{db_password}@127.0.0.1:5432/Final Project"
engine = create_engine(db_string)
shanghai.to_sql(name='deal_shanghai', con=engine, if_exists='replace')
beijing.to_sql(name='deal_beijing', con=engine, if_exists='replace')
